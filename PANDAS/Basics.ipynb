# %% [markdown]
# ## lets start Pandas

# %%
import pandas as pd
## gcsfs library for reading cloud data

# %%
## to read csv file,excel,JSON etc | encodinng change if error comes UTF-8 or latin1
df = pd.read_csv("sales_data_sample.csv" ,encoding="latin1")

# %%
## shows top 5 from the table | df.head(n) for n no of rows
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...

# %%
df.tail() ## last 5 rows | df.tail(n) for n no of rows
# Out:
#     name  age    city
# 0    ram   10  nagpur
# 1  shyam   20  mumbai
# 2   vasu   30    pune

# %%
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# ...

# %% [markdown]
# ## dataframe to csv and other file

# %%
data = {
    'name' : ['ram','shyam','vasu'],
    'age' : [10,20,30],
    'city' : ['nagpur','mumbai','pune']
}
df= pd.DataFrame(data) ## converted data to dataframe

# %%
print(df)
# Out:
#     name  age    city
# 0    ram   10  nagpur
# 1  shyam   20  mumbai
# 2   vasu   30    pune

# %%
df.to_csv("output.csv" , index=False) 
# to save file into diff Extensions | also index false for no indexing on the file

# %% [markdown]
# ## INFO METHOD -
#  1.no of rows and column 2.column name 3.datatype 4.non_null counts 5.memory usage

# %%
df=pd.read_csv("sales_data_sample.csv", encoding="latin1")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2823 entries, 0 to 2822
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       2823 non-null   int64
#  1   QUANTITYORDERED   2823 non-null   int64
#  2   PRICEEACH         2823 non-null   float64
#  3   ORDERLINENUMBER   2823 non-null   int64
#  4   SALES             2823 non-null   float64
#  5   ORDERDATE         2823 non-null   object
#  6   STATUS            2823 non-null   object
#  7   QTR_ID            2823 non-null   int64
#  8   MONTH_ID          2823 non-null   int64
#  9   YEAR_ID           2823 non-null   int64
#  10  PRODUCTLINE       2823 non-null   object
#  11  MSRP              2823 non-null   int64
#  12  PRODUCTCODE       2823 non-null   object
#  13  CUSTOMERNAME      2823 non-null   object
#  14  PHONE             2823 non-null   object
#  15  ADDRESSLINE1      2823 non-null   object
# ...

# %% [markdown]
# # describe
#  for statistical analysis

# %%
df.describe()
# Out:
#         ORDERNUMBER  QUANTITYORDERED    PRICEEACH  ORDERLINENUMBER  \
# count   2823.000000      2823.000000  2823.000000      2823.000000
# mean   10258.725115        35.092809    83.658544         6.466171
# std       92.085478         9.741443    20.174277         4.225841
# min    10100.000000         6.000000    26.880000         1.000000
# 25%    10180.000000        27.000000    68.860000         3.000000
# 50%    10262.000000        35.000000    95.700000         6.000000
# 75%    10333.500000        43.000000   100.000000         9.000000
# max    10425.000000        97.000000   100.000000        18.000000
#
#               SALES       QTR_ID     MONTH_ID     YEAR_ID         MSRP
# count   2823.000000  2823.000000  2823.000000  2823.00000  2823.000000
# mean    3553.889072     2.717676     7.092455  2003.81509   100.715551
# std     1841.865106     1.203878     3.656633     0.69967    40.187912
# min      482.130000     1.000000     1.000000  2003.00000    33.000000
# ...

# %% [markdown]
# ## shape(no of rows,no of columns) and column(name of columns)

# %%
df.shape
# Out:
# (2823, 25)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'YEAR_ID',
#        'PRODUCTLINE', 'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE',
#        'ADDRESSLINE1', 'ADDRESSLINE2', 'CITY', 'STATE', 'POSTALCODE',
#        'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME', 'CONTACTFIRSTNAME',
#        'DEALSIZE'],
#       dtype='object')

# %% [markdown]
# # 1-select specific column
# # 2.filter
# # 3.conditions

# %%
col = df["CITY"]
print(col)
col2= df[["COUNTRY", "STATE","CITY"]] ## for multiple column pass a list
print(col2)
# Out:
# 0                 NYC
# 1               Reims
# 2               Paris
# 3            Pasadena
# 4       San Francisco
#             ...
# 2818           Madrid
# 2819             Oulu
# 2820           Madrid
# 2821         Toulouse
# 2822           Boston
# Name: CITY, Length: 2823, dtype: object
#       COUNTRY STATE           CITY
# 0         USA    NY            NYC
# 1      France   NaN          Reims
# 2      France   NaN          Paris
# 3         USA    CA       Pasadena
# 4         USA    CA  San Francisco
# ...       ...   ...            ...
# 2818    Spain   NaN         Madrid
# 2819  Finland   NaN           Oulu
# 2820    Spain   NaN         Madrid
# 2821   France   NaN       Toulouse
# 2822      USA    MA         Boston
#
# [2823 rows x 3 columns]

# %%
## filtering
#filter_data = df[df["CITY"] == "NYC"]
#print(filter_data)
## for multiple conditions
filter_data_multiple = df[(df["CITY"] == "NYC") & (df["YEAR_ID"] == 2003)]
print(filter_data_multiple)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 0           10107               30      95.70                2   2871.00
# 31          10163               21     100.00                1   4860.24
# 54          10107               39      99.91                5   3896.49
# 80          10107               27     100.00                4   6065.55
# 188         10127               46     100.00                2  11279.20
# 240         10107               21     100.00                1   3036.60
# 268         10127               46     100.00                3   7366.44
# 318         10127               42     100.00                1   8138.76
# 368         10115               46     100.00                5   5723.78
# 369         10127               24     100.00               11   2559.60
# 456         10204               42     100.00               17   6182.40
# 475         10102               39     100.00                2   4808.31
# ...

# %% [markdown]
# # adding a new column

# %%
df["discount_10_percent"]= df["SALES"] * 0.1 ## creates a new column at the end
print(df)
# Out:
#       ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0           10107               30      95.70                2  2871.00
# 1           10121               34      81.35                5  2765.90
# 2           10134               41      94.74                2  3884.34
# 3           10145               45      83.26                6  3746.70
# 4           10159               49     100.00               14  5205.27
# ...           ...              ...        ...              ...      ...
# 2818        10350               20     100.00               15  2244.40
# 2819        10373               29     100.00                1  3978.51
# 2820        10386               43     100.00                4  5417.57
# 2821        10397               34      62.24                1  2116.16
# 2822        10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %% [markdown]
# ## using INSERT METHOD | df.insert(index no , column name , values)

# %% [markdown]
# ## access and update a particular cell
# df.loc[row_no,col_name] = "new value"

# %%
df.loc[0,"SALES"] = 3000
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  3000.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...          NaN
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...          NaN
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...          NaN
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...          NaN
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...          NaN
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# ...

# %% [markdown]
# # renaming column
#  df.rename(columns{"old column name" : "new column name "})

# %%
renamed = df.rename(columns={"ORDERNUMBER" : "ORDER_NUMBER"})
print(renamed)
# Out:
#       ORDER_NUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0            10107               30      95.70                2  3000.00
# 1            10121               34      81.35                5  2765.90
# 2            10134               41      94.74                2  3884.34
# 3            10145               45      83.26                6  3746.70
# 4            10159               49     100.00               14  5205.27
# ...            ...              ...        ...              ...      ...
# 2818         10350               20     100.00               15  2244.40
# 2819         10373               29     100.00                1  3978.51
# 2820         10386               43     100.00                4  5417.57
# 2821         10397               34      62.24                1  2116.16
# 2822         10414               47      65.52                9  3079.44
#
#             ORDERDATE    STATUS  QTR_ID  MONTH_ID  YEAR_ID  ... ADDRESSLINE2  \
# ...

# %% [markdown]
# # delete  a column
#  df.drop(column=["name of column], inplace true/false)

# %%
df.drop(columns=["discount_10_percent"] , inplace=True) ## inplace true for changing in main file 
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  3000.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  ...  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  ...
# 1    5/7/2003 0:00  Shipped       2         5     2003  ...
# 2    7/1/2003 0:00  Shipped       3         7     2003  ...
# 3   8/25/2003 0:00  Shipped       3         8     2003  ...
# 4  10/10/2003 0:00  Shipped       4        10     2003  ...
#
#                     ADDRESSLINE1  ADDRESSLINE2           CITY STATE  \
# 0        897 Long Airport Avenue           NaN            NYC    NY
# ...
